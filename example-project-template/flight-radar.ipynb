# %%
# !pip install flightradar24

# %%
import flightradar24

flight_id = 'CF9033' # Turkish Airlines' Istanbul - New York flight
fr = flightradar24.Api()
flight = fr.get_flight(flight_id)

# %%
flight['result']['response']
# Out:
# {'item': {'current': 15, 'total': None, 'limit': 25},
#  'page': {'current': 1, 'more': False, 'total': None},
#  'timestamp': 1754237966,
#  'data': [{'identification': {'id': None,
#     'row': 5696380563,
#     'number': {'default': 'CF9033', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Scheduled',
#     'icon': None,
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'scheduled',
#       'type': 'departure',
#       'color': 'gray',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '73F', 'text': None},
#     'hex': None,
#     'registration': None,
#     'serialNo': None,
#     'age': None,
#     'restricted': None,
#     'availability': {'serialNo': None, 'age': None}},
#    'owner': None,
#    'airline': {'name': 'China Postal Airlines',
#     'code': {'iata': 'CF', 'icao': 'CYZ'}},
# ...
